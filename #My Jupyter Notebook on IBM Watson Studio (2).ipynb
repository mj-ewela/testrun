# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# MARY-JANE

# %% [markdown]
# Data scientist

# %% [markdown]
# _i am interested in data science because i would like to help the healthcare industry with making accurate predictions on what drugs would cure specific diseases. This saves time, money and resources_

# %% [markdown]
# ###cell 5 is supposed to calculate the difference between 5 and 2

# %%
5-2
# Out:
# 3

# %% [markdown]
# ![Screenshot (32).png](attachment:13c1b476-1050-49ef-aa9a-bee873c692cc.png)
#  - first on the list
#   - second item
# ~cancel~
